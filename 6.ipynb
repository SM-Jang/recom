# %%
# Load Data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
PATH = 'C:/RecoSys/Data/'
r_cols = ['user_id','movie_id','rating','timestamp']
ratings = pd.read_csv(PATH+'u.data', sep='\t', names=r_cols, encoding='latin-1')
ratings = ratings[['user_id', 'movie_id', 'rating']].astype(int)

ratings_train, ratings_test = train_test_split(ratings, train_size=0.75, shuffle=True)
print(ratings_train.shape, ratings_test.shape)
# Out:
# (75000, 3) (25000, 3)

# %%
#### (1)
# SVD(MF) using DL
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dot, Add, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adamax

# Variable 초기화
K = 200                     # latent factor 수
mu = ratings_train.rating.mean()   # 전체 평균
M = ratings.user_id.max()+1 # Number of users
N = ratings.movie_id.max()+1# Number of items

# Defining RMSE measure
def RMSE(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true-y_pred)))

# Keras Model
user = Input(shape=(1,))
item = Input(shape=(1,))
P_embedding = Embedding(M, K, embeddings_regularizer=l2())(user) # P: [M, K]
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user) # user bias: [M, 1]

Q_embedding = Embedding(N, K, embeddings_regularizer=l2())(item) # Q: [N, K]
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item) # item bias: [N, 1]

R = layers.dot([P_embedding, Q_embedding], axes=2)
R = layers.add([R, user_bias, item_bias])
R = Flatten()(R)

# %%
# Model Setting
model = Model(inputs = [user, item], outputs = R)
model.compile(
    loss = RMSE,
    optimizer=SGD(),
    metrics=[RMSE]
)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 1, 200)       188800      input_5[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 1, 200)       336600      input_6[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1, 1)         0           embedding_8[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 1, 1)         944         input_5[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 1, 1)         1683        input_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 1)         0           dot_2[0][0]
#                                                                  embedding_9[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           add_2[0][0]
# ==================================================================================================
# Total params: 528,027
# Trainable params: 528,027
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Model Fitting
result = model.fit(
    x = [ratings_train.user_id.values, ratings_train.movie_id.values],
    y = ratings_train.rating.values - mu,
    epochs = 60,
    batch_size=256,
    validation_data=(
        [ratings_test.user_id.values, ratings_test.movie_id.values],
        ratings_test.rating.values-mu
    )
)
# Out:
# Train on 75000 samples, validate on 25000 samples
# Epoch 1/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 5.2790 - RMSE: 1.1253 - val_loss: 5.0415 - val_RMSE: 1.1272
# Epoch 2/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 4.8175 - RMSE: 1.1233 - val_loss: 4.6063 - val_RMSE: 1.1254
# Epoch 3/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 4.4069 - RMSE: 1.1212 - val_loss: 4.2198 - val_RMSE: 1.1238
# Epoch 4/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 4.0418 - RMSE: 1.1194 - val_loss: 3.8759 - val_RMSE: 1.1219
# Epoch 5/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 3.7172 - RMSE: 1.1177 - val_loss: 3.5700 - val_RMSE: 1.1199
# Epoch 6/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 3.4285 - RMSE: 1.1161 - val_loss: 3.2983 - val_RMSE: 1.1193
# Epoch 7/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 3.1717 - RMSE: 1.1146 - val_loss: 3.0564 - val_RMSE: 1.1177
# Epoch 8/60
# 75000/75000 [==============================] - 1s 18us/sample - loss: 2.9433 - RMSE: 1.1132 - val_loss: 2.8411 - val_RMSE: 1.1163
# Epoch 9/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 2.7403 - RMSE: 1.1121 - val_loss: 2.6499 - val_RMSE: 1.1151
# Epoch 10/60
# 75000/75000 [==============================] - 1s 19us/sample - loss: 2.5597 - RMSE: 1.1108 - val_loss: 2.4799 - val_RMSE: 1.1145
# Epoch 11/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 2.3992 - RMSE: 1.1099 - val_loss: 2.3285 - val_RMSE: 1.1133
# Epoch 12/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 2.2564 - RMSE: 1.1088 - val_loss: 2.1940 - val_RMSE: 1.1121
# Epoch 13/60
# 75000/75000 [==============================] - 1s 18us/sample - loss: 2.1292 - RMSE: 1.1078 - val_loss: 2.0745 - val_RMSE: 1.1115
# Epoch 14/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 2.0163 - RMSE: 1.1069 - val_loss: 1.9680 - val_RMSE: 1.1108
# Epoch 15/60
# 75000/75000 [==============================] - 1s 18us/sample - loss: 1.9158 - RMSE: 1.1061 - val_loss: 1.8734 - val_RMSE: 1.1099
# Epoch 16/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 1.8264 - RMSE: 1.1053 - val_loss: 1.7892 - val_RMSE: 1.1090
# Epoch 17/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 1.7471 - RMSE: 1.1047 - val_loss: 1.7142 - val_RMSE: 1.1084
# Epoch 18/60
# 75000/75000 [==============================] - 1s 18us/sample - loss: 1.6763 - RMSE: 1.1039 - val_loss: 1.6477 - val_RMSE: 1.1079
# Epoch 19/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 1.6135 - RMSE: 1.1034 - val_loss: 1.5885 - val_RMSE: 1.1071
# Epoch 20/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 1.5576 - RMSE: 1.1028 - val_loss: 1.5357 - val_RMSE: 1.1066
# Epoch 21/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 1.5079 - RMSE: 1.1022 - val_loss: 1.4893 - val_RMSE: 1.1062
# Epoch 22/60
# 75000/75000 [==============================] - 1s 18us/sample - loss: 1.4637 - RMSE: 1.1017 - val_loss: 1.4476 - val_RMSE: 1.1060
# Epoch 23/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.4244 - RMSE: 1.1013 - val_loss: 1.4107 - val_RMSE: 1.1055
# Epoch 24/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.3894 - RMSE: 1.1008 - val_loss: 1.3775 - val_RMSE: 1.1051
# Epoch 25/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.3583 - RMSE: 1.1003 - val_loss: 1.3482 - val_RMSE: 1.1043
# Epoch 26/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.3307 - RMSE: 1.1001 - val_loss: 1.3222 - val_RMSE: 1.1040
# Epoch 27/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.3061 - RMSE: 1.0997 - val_loss: 1.2985 - val_RMSE: 1.1032
# Epoch 28/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.2842 - RMSE: 1.0994 - val_loss: 1.2786 - val_RMSE: 1.1040
# Epoch 29/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.2647 - RMSE: 1.0990 - val_loss: 1.2603 - val_RMSE: 1.1033
# Epoch 30/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.2474 - RMSE: 1.0987 - val_loss: 1.2441 - val_RMSE: 1.1033
# Epoch 31/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.2321 - RMSE: 1.0985 - val_loss: 1.2296 - val_RMSE: 1.1029
# Epoch 32/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.2184 - RMSE: 1.0982 - val_loss: 1.2165 - val_RMSE: 1.1027
# Epoch 33/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.2062 - RMSE: 1.0980 - val_loss: 1.2053 - val_RMSE: 1.1026
# Epoch 34/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1954 - RMSE: 1.0978 - val_loss: 1.1951 - val_RMSE: 1.1024
# Epoch 35/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1857 - RMSE: 1.0975 - val_loss: 1.1860 - val_RMSE: 1.1023
# Epoch 36/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1772 - RMSE: 1.0974 - val_loss: 1.1779 - val_RMSE: 1.1020
# Epoch 37/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1695 - RMSE: 1.0971 - val_loss: 1.1707 - val_RMSE: 1.1019
# Epoch 38/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1628 - RMSE: 1.0970 - val_loss: 1.1643 - val_RMSE: 1.1014
# Epoch 39/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1567 - RMSE: 1.0968 - val_loss: 1.1587 - val_RMSE: 1.1017
# Epoch 40/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1515 - RMSE: 1.0967 - val_loss: 1.1535 - val_RMSE: 1.1011
# Epoch 41/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1467 - RMSE: 1.0965 - val_loss: 1.1489 - val_RMSE: 1.1009
# Epoch 42/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1425 - RMSE: 1.0965 - val_loss: 1.1452 - val_RMSE: 1.1012
# Epoch 43/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1388 - RMSE: 1.0964 - val_loss: 1.1416 - val_RMSE: 1.1011
# Epoch 44/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1354 - RMSE: 1.0962 - val_loss: 1.1385 - val_RMSE: 1.1012
# Epoch 45/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1323 - RMSE: 1.0960 - val_loss: 1.1357 - val_RMSE: 1.1007
# Epoch 46/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1298 - RMSE: 1.0961 - val_loss: 1.1330 - val_RMSE: 1.1004
# Epoch 47/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 1.1273 - RMSE: 1.0958 - val_loss: 1.1311 - val_RMSE: 1.1005
# Epoch 48/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1253 - RMSE: 1.0958 - val_loss: 1.1289 - val_RMSE: 1.1001
# Epoch 49/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1233 - RMSE: 1.0957 - val_loss: 1.1274 - val_RMSE: 1.1004
# Epoch 50/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 1.1216 - RMSE: 1.0955 - val_loss: 1.1258 - val_RMSE: 1.1003
# Epoch 51/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1203 - RMSE: 1.0956 - val_loss: 1.1244 - val_RMSE: 1.1006
# Epoch 52/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 1.1190 - RMSE: 1.0956 - val_loss: 1.1230 - val_RMSE: 1.1001
# Epoch 53/60
# 75000/75000 [==============================] - 1s 17us/sample - loss: 1.1178 - RMSE: 1.0954 - val_loss: 1.1220 - val_RMSE: 1.1000
# Epoch 54/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1167 - RMSE: 1.0953 - val_loss: 1.1212 - val_RMSE: 1.1003
# Epoch 55/60
# 75000/75000 [==============================] - 1s 14us/sample - loss: 1.1156 - RMSE: 1.0951 - val_loss: 1.1201 - val_RMSE: 1.1001
# Epoch 56/60
# 75000/75000 [==============================] - 1s 16us/sample - loss: 1.1149 - RMSE: 1.0952 - val_loss: 1.1193 - val_RMSE: 1.1000
# Epoch 57/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1143 - RMSE: 1.0952 - val_loss: 1.1188 - val_RMSE: 1.0996
# Epoch 58/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1137 - RMSE: 1.0953 - val_loss: 1.1182 - val_RMSE: 1.1000
# Epoch 59/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1131 - RMSE: 1.0951 - val_loss: 1.1173 - val_RMSE: 1.0997
# Epoch 60/60
# 75000/75000 [==============================] - 1s 15us/sample - loss: 1.1126 - RMSE: 1.0951 - val_loss: 1.1172 - val_RMSE: 1.0999

# %%
# Plot RMSE
import matplotlib.pyplot as plt
plt.plot(result.history['RMSE'], label="Train RMSE")
plt.plot(result.history['val_RMSE'], label='Test RMSE')
plt.legend()
plt.show()

# %%
# Prediction
user_ids = ratings_test.user_id.values[:6]
movie_ids = ratings_test.movie_id.values[:6]
predictions = model.predict([user_ids, movie_ids])+mu
print('Actuals:\n', ratings_test[:6])
print()
print('Predictions:\n', predictions)
# Out:
# Actuals:
#         user_id  movie_id  rating
# 40607      640       720       3
# 45349       21       564       3
# 26605        6       321       3
# 76723      666       546       4
# 61559       22         4       5
# 92050      882       407       2
#
# Predictions:
#  [[3.5471365]
#  [3.455381 ]
#  [3.5167508]
#  [3.4930294]
#  [3.5284672]
#  [3.5434947]]

# %%
# RMSE check
def RMSE2(y_true, y_pred):
    return np.sqrt(np.mean((np.array(y_true) - np.array(y_pred))**2))

user_ids = ratings_test.user_id.values
movie_ids = ratings_test.movie_id.values
y_pred = model.predict([user_ids, movie_ids]) + mu
y_pred = np.ravel(y_pred, order='C')
y_true = np.array(ratings_test.rating)

RMSE2(y_true, y_pred)

# %%
# Load Data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
PATH = 'C:/RecoSys/Data/'
r_cols = ['user_id','movie_id','rating','timestamp']
ratings = pd.read_csv(PATH+'u.data', sep='\t', names=r_cols, encoding='latin-1')
ratings = ratings[['user_id', 'movie_id', 'rating']].astype(int)

ratings_train, ratings_test = train_test_split(ratings, train_size=0.75, shuffle=True)
print(ratings_train.shape, ratings_test.shape)
# Out:
# (75000, 3) (25000, 3)

# %%
##### (1)

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dot, Add, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adam, Adamax

# Variable 초기화 
K = 200                             # Latent factor 수 
mu = ratings_train.rating.mean()    # 전체 평균 
M = ratings.user_id.max() + 1       # Number of users
N = ratings.movie_id.max() + 1      # Number of movies

# Defining RMSE measure
def RMSE(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
##### (2)

# Keras model
user = Input(shape=(1, ))                                               # User input
item = Input(shape=(1, ))                                               # Item input
P_embedding = Embedding(M, K, embeddings_regularizer=l2())(user)        # (M, 1, K)
Q_embedding = Embedding(N, K, embeddings_regularizer=l2())(item)        # (N, 1, K)
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user)          # User bias term (M, 1, )
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item)          # Item bias term (N, 1, )

# Concatenate layers
from tensorflow.keras.layers import Dense, Concatenate, Activation
P_embedding = Flatten()(P_embedding)                                    # (K, )
Q_embedding = Flatten()(Q_embedding)                                    # (K, )
user_bias = Flatten()(user_bias)                                        # (1, )
item_bias = Flatten()(item_bias)                                        # (1, )
R = Concatenate()([P_embedding, Q_embedding, user_bias, item_bias])     # (2K + 2, )

# Neural network
R = Dense(2048)(R)
R = Activation('linear')(R)
R = Dense(256)(R)
R = Activation('linear')(R)
R = Dense(1)(R)

model = Model(inputs=[user, item], outputs=R)
model.compile(
  loss=RMSE,
  optimizer=SGD(),
  #optimizer=Adamax(),
  metrics=[RMSE]
)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\smsm8\miniconda3\envs\kooc\lib\site-packages\tensorflow_core\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\Users\smsm8\miniconda3\envs\kooc\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 200)       188800      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 200)       336600      input_2[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 1)         944         input_1[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 1)         1683        input_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 200)          0           embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 200)          0           embedding_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           embedding_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1)            0           embedding_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 402)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         825344      concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          524544      activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         activation_1[0][0]
# ==================================================================================================
# Total params: 1,878,172
# Trainable params: 1,878,172
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Model Fitting
result = model.fit(
    x = [ratings_train.user_id.values, ratings_train.movie_id.values],
    y = ratings_train.rating.values - mu,
    epochs = 60,
    batch_size=512,
    validation_data=(
        [ratings_test.user_id.values, ratings_test.movie_id.values],
        ratings_test.rating.values-mu
    )
)
# Out:
# Train on 75000 samples, validate on 25000 samples
# Epoch 1/60
#   512/75000 [..............................] - ETA: 3s - loss: 4.8195 - RMSE: 1.1000ERROR! Session/line number was not unique in database. History logging moved to new session 369
# 75000/75000 [==============================] - 4s 50us/sample - loss: 4.7331 - RMSE: 1.1198 - val_loss: 4.6210 - val_RMSE: 1.1139
# Epoch 2/60
# 75000/75000 [==============================] - 4s 49us/sample - loss: 4.5249 - RMSE: 1.1175 - val_loss: 4.4193 - val_RMSE: 1.1120
# Epoch 3/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 4.3286 - RMSE: 1.1157 - val_loss: 4.2287 - val_RMSE: 1.1101
# Epoch 4/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 4.1431 - RMSE: 1.1135 - val_loss: 4.0484 - val_RMSE: 1.1076
# Epoch 5/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 3.9681 - RMSE: 1.1109 - val_loss: 3.8786 - val_RMSE: 1.1053
# Epoch 6/60
# 75000/75000 [==============================] - 4s 53us/sample - loss: 3.8026 - RMSE: 1.1084 - val_loss: 3.7179 - val_RMSE: 1.1024
# Epoch 7/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 3.6462 - RMSE: 1.1051 - val_loss: 3.5657 - val_RMSE: 1.0992
# Epoch 8/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 3.4982 - RMSE: 1.1017 - val_loss: 3.4215 - val_RMSE: 1.0954
# Epoch 9/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 3.3579 - RMSE: 1.0975 - val_loss: 3.2856 - val_RMSE: 1.0914
# Epoch 10/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 3.2249 - RMSE: 1.0931 - val_loss: 3.1566 - val_RMSE: 1.0867
# Epoch 11/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 3.0987 - RMSE: 1.0873 - val_loss: 3.0334 - val_RMSE: 1.0810
# Epoch 12/60
# 75000/75000 [==============================] - 4s 53us/sample - loss: 2.9789 - RMSE: 1.0814 - val_loss: 2.9169 - val_RMSE: 1.0747
# Epoch 13/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 2.8648 - RMSE: 1.0745 - val_loss: 2.8058 - val_RMSE: 1.0676
# Epoch 14/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 2.7561 - RMSE: 1.0665 - val_loss: 2.7002 - val_RMSE: 1.0599
# Epoch 15/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 2.6528 - RMSE: 1.0588 - val_loss: 2.5996 - val_RMSE: 1.0518
# Epoch 16/60
# 75000/75000 [==============================] - 4s 51us/sample - loss: 2.5545 - RMSE: 1.0498 - val_loss: 2.5039 - val_RMSE: 1.0430
# Epoch 17/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 2.4607 - RMSE: 1.0407 - val_loss: 2.4139 - val_RMSE: 1.0345
# Epoch 18/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 2.3719 - RMSE: 1.0308 - val_loss: 2.3270 - val_RMSE: 1.0245
# Epoch 19/60
# 75000/75000 [==============================] - 4s 52us/sample - loss: 2.2875 - RMSE: 1.0213 - val_loss: 2.2460 - val_RMSE: 1.0163
# Epoch 20/60
# 75000/75000 [==============================] - 4s 53us/sample - loss: 2.2078 - RMSE: 1.0124 - val_loss: 2.1688 - val_RMSE: 1.0075
# Epoch 21/60
# 75000/75000 [==============================] - 5s 62us/sample - loss: 2.1325 - RMSE: 1.0038 - val_loss: 2.0966 - val_RMSE: 0.9999
# Epoch 22/60
# 75000/75000 [==============================] - 5s 71us/sample - loss: 2.0616 - RMSE: 0.9956 - val_loss: 2.0283 - val_RMSE: 0.9926
# Epoch 23/60
# 75000/75000 [==============================] - 6s 75us/sample - loss: 1.9948 - RMSE: 0.9880 - val_loss: 1.9639 - val_RMSE: 0.9856
# Epoch 24/60
# 75000/75000 [==============================] - 5s 72us/sample - loss: 1.9319 - RMSE: 0.9809 - val_loss: 1.9036 - val_RMSE: 0.9798
# Epoch 25/60
# 75000/75000 [==============================] - 5s 73us/sample - loss: 1.8727 - RMSE: 0.9744 - val_loss: 1.8476 - val_RMSE: 0.9751
# Epoch 26/60
# 75000/75000 [==============================] - 5s 71us/sample - loss: 1.8175 - RMSE: 0.9690 - val_loss: 1.7949 - val_RMSE: 0.9707
# Epoch 27/60
# 75000/75000 [==============================] - 5s 67us/sample - loss: 1.7654 - RMSE: 0.9642 - val_loss: 1.7448 - val_RMSE: 0.9663
# Epoch 28/60
# 75000/75000 [==============================] - 5s 60us/sample - loss: 1.7165 - RMSE: 0.9595 - val_loss: 1.6979 - val_RMSE: 0.9624
# Epoch 29/60
# 75000/75000 [==============================] - 4s 55us/sample - loss: 1.6705 - RMSE: 0.9554 - val_loss: 1.6543 - val_RMSE: 0.9598
# Epoch 30/60
# 75000/75000 [==============================] - 4s 59us/sample - loss: 1.6272 - RMSE: 0.9514 - val_loss: 1.6131 - val_RMSE: 0.9567
# Epoch 31/60
# 75000/75000 [==============================] - 5s 65us/sample - loss: 1.5866 - RMSE: 0.9483 - val_loss: 1.5739 - val_RMSE: 0.9539
# Epoch 32/60
# 75000/75000 [==============================] - 5s 72us/sample - loss: 1.5483 - RMSE: 0.9455 - val_loss: 1.5381 - val_RMSE: 0.9523
# Epoch 33/60
# 75000/75000 [==============================] - 6s 73us/sample - loss: 1.5122 - RMSE: 0.9427 - val_loss: 1.5041 - val_RMSE: 0.9507
# Epoch 34/60
# 75000/75000 [==============================] - 6s 74us/sample - loss: 1.4785 - RMSE: 0.9401 - val_loss: 1.4715 - val_RMSE: 0.9485
# Epoch 35/60
# 75000/75000 [==============================] - 5s 69us/sample - loss: 1.4470 - RMSE: 0.9381 - val_loss: 1.4410 - val_RMSE: 0.9467
# Epoch 36/60
# 75000/75000 [==============================] - 5s 64us/sample - loss: 1.4169 - RMSE: 0.9360 - val_loss: 1.4127 - val_RMSE: 0.9455
# Epoch 37/60
# 75000/75000 [==============================] - 4s 56us/sample - loss: 1.3888 - RMSE: 0.9345 - val_loss: 1.3866 - val_RMSE: 0.9452
# Epoch 38/60
# 75000/75000 [==============================] - 4s 57us/sample - loss: 1.3623 - RMSE: 0.9328 - val_loss: 1.3608 - val_RMSE: 0.9434
# Epoch 39/60
# 75000/75000 [==============================] - 5s 65us/sample - loss: 1.3375 - RMSE: 0.9315 - val_loss: 1.3371 - val_RMSE: 0.9428
# Epoch 40/60
# 75000/75000 [==============================] - 6s 77us/sample - loss: 1.3140 - RMSE: 0.9302 - val_loss: 1.3153 - val_RMSE: 0.9421
# Epoch 41/60
# 75000/75000 [==============================] - 6s 76us/sample - loss: 1.2919 - RMSE: 0.9289 - val_loss: 1.2938 - val_RMSE: 0.9411
# Epoch 42/60
# 75000/75000 [==============================] - 5s 68us/sample - loss: 1.2711 - RMSE: 0.9279 - val_loss: 1.2745 - val_RMSE: 0.9409
# Epoch 43/60
# 75000/75000 [==============================] - 5s 64us/sample - loss: 1.2516 - RMSE: 0.9272 - val_loss: 1.2552 - val_RMSE: 0.9398
# Epoch 44/60
# 75000/75000 [==============================] - 4s 58us/sample - loss: 1.2334 - RMSE: 0.9265 - val_loss: 1.2421 - val_RMSE: 0.9440
# Epoch 45/60
# 75000/75000 [==============================] - 4s 55us/sample - loss: 1.2161 - RMSE: 0.9257 - val_loss: 1.2230 - val_RMSE: 0.9405
# Epoch 46/60
# 75000/75000 [==============================] - 5s 61us/sample - loss: 1.1999 - RMSE: 0.9250 - val_loss: 1.2071 - val_RMSE: 0.9400
# Epoch 47/60
# 75000/75000 [==============================] - 5s 67us/sample - loss: 1.1843 - RMSE: 0.9243 - val_loss: 1.1910 - val_RMSE: 0.9382
# Epoch 48/60
# 75000/75000 [==============================] - 5s 70us/sample - loss: 1.1699 - RMSE: 0.9241 - val_loss: 1.1766 - val_RMSE: 0.9375
# Epoch 49/60
# 75000/75000 [==============================] - 5s 69us/sample - loss: 1.1562 - RMSE: 0.9236 - val_loss: 1.1645 - val_RMSE: 0.9380
# Epoch 50/60
# 75000/75000 [==============================] - 5s 70us/sample - loss: 1.1433 - RMSE: 0.9229 - val_loss: 1.1518 - val_RMSE: 0.9375
# Epoch 51/60
# 75000/75000 [==============================] - 5s 68us/sample - loss: 1.1314 - RMSE: 0.9229 - val_loss: 1.1400 - val_RMSE: 0.9368
# Epoch 52/60
# 75000/75000 [==============================] - 5s 62us/sample - loss: 1.1200 - RMSE: 0.9225 - val_loss: 1.1287 - val_RMSE: 0.9367
# Epoch 53/60
# 75000/75000 [==============================] - 4s 58us/sample - loss: 1.1092 - RMSE: 0.9220 - val_loss: 1.1195 - val_RMSE: 0.9376
# Epoch 54/60
# 75000/75000 [==============================] - 5s 66us/sample - loss: 1.0993 - RMSE: 0.9225 - val_loss: 1.1121 - val_RMSE: 0.9398
# Epoch 55/60
# 75000/75000 [==============================] - 5s 68us/sample - loss: 1.0898 - RMSE: 0.9217 - val_loss: 1.1056 - val_RMSE: 0.9425
# Epoch 56/60
# 75000/75000 [==============================] - 5s 66us/sample - loss: 1.0806 - RMSE: 0.9216 - val_loss: 1.0921 - val_RMSE: 0.9375
# Epoch 57/60
# 75000/75000 [==============================] - 5s 64us/sample - loss: 1.0719 - RMSE: 0.9212 - val_loss: 1.0838 - val_RMSE: 0.9372
# Epoch 58/60
# 75000/75000 [==============================] - 5s 68us/sample - loss: 1.0642 - RMSE: 0.9212 - val_loss: 1.0776 - val_RMSE: 0.9384
# Epoch 59/60
# 75000/75000 [==============================] - 5s 67us/sample - loss: 1.0570 - RMSE: 0.9216 - val_loss: 1.0677 - val_RMSE: 0.9360
# Epoch 60/60
# 75000/75000 [==============================] - 5s 62us/sample - loss: 1.0497 - RMSE: 0.9213 - val_loss: 1.0634 - val_RMSE: 0.9384

# %%
# Plot RMSE
import matplotlib.pyplot as plt
plt.plot(result.history['RMSE'], label="Train RMSE")
plt.plot(result.history['val_RMSE'], label="Test RMSE")
plt.xlabel('epoch')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# Prediction
user_ids = ratings_test.user_id.values[0:6]
movie_ids = ratings_test.movie_id.values[0:6]
predictions = model.predict([user_ids, movie_ids]) + mu
print("Actuals: \n", ratings_test[0:6])
print()
print("Predictions: \n", predictions)

# 정확도(RMSE)를 계산하는 함수 
def RMSE2(y_true, y_pred):
    return np.sqrt(np.mean((np.array(y_true) - np.array(y_pred))**2))

user_ids = ratings_test.user_id.values
movie_ids = ratings_test.movie_id.values
y_pred = model.predict([user_ids, movie_ids]) + mu
y_pred = np.ravel(y_pred, order='C')
y_true = np.array(ratings_test.rating)

RMSE2(y_true, y_pred)
# Out:
# Actuals:
#         user_id  movie_id  rating
# 30487      552       151       3
# 30616      405       556       1
# 62040      615       678       1
# 23171        1         2       3
# 49687      450       202       4
# 85204      168       845       4
#
# Predictions:
#  [[3.33565  ]
#  [1.4164922]
#  [2.7154036]
#  [3.3131702]
#  [4.0727644]
#  [3.4784148]]
# 0.9386359172490512
